# %% [markdown]
# <a href="https://colab.research.google.com/github/gabirc26/ind3/blob/main/individual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importação de bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configurar estilo dos gráficos
sns.set(style="whitegrid")

# %%
# Exemplo de criação de dados para análise
data = {
    'Data': ['Segunda', 'Terca', 'Quarta', 'Quinta', 'Sexta', 'Sabado', 'Domingo'],
    'Horas Trabalhadas': [6, 7, 8, 6, 7, 5, 4],
    'Tarefas Concluídas': [5, 4, 6, 4, 5, 3, 2],
    'Bugs Corrigidos': [3, 2, 1, 4, 3, 2, 1]
}

df = pd.DataFrame(data)

# Exibir as primeiras linhas do dataframe
df.head()
# Out:
#       Data  Horas Trabalhadas  Tarefas Concluídas  Bugs Corrigidos
# 0  Segunda                  6                   5                3
# 1    Terca                  7                   4                2
# 2   Quarta                  8                   6                1
# 3   Quinta                  6                   4                4
# 4    Sexta                  7                   5                3

# %%
total_horas_trabalhadas = df['Horas Trabalhadas'].sum()
print(f'Total de Horas Trabalhadas: {total_horas_trabalhadas}')
# Out:
# Total de Horas Trabalhadas: 43

# %%
media_horas_trabalhadas = df['Horas Trabalhadas'].mean()
print(f'Média Diária de Horas Trabalhadas: {media_horas_trabalhadas:.2f}')
# Out:
# Média Diária de Horas Trabalhadas: 6.14

# %%
total_bugs_corrigidos = df['Bugs Corrigidos'].sum()
print(f'Total de Bugs Corrigidos: {total_bugs_corrigidos}')
# Out:
# Total de Bugs Corrigidos: 16

# %%
media_bugs_corrigidos = df['Bugs Corrigidos'].mean()
print(f'Média Diária de Bugs Corrigidos: {media_bugs_corrigidos:.2f}')
# Out:
# Média Diária de Bugs Corrigidos: 2.29

# %%
total_tarefas_concluidas = df['Tarefas Concluídas'].sum()
print(f'Total de Tarefas Concluídas: {total_tarefas_concluidas}')
# Out:
# Total de Tarefas Concluídas: 29

# %%
media_tarefas_concluidas = df['Tarefas Concluídas'].mean()
print(f'Média Diária de Tarefas Concluídas: {media_tarefas_concluidas:.2f}')
# Out:
# Média Diária de Tarefas Concluídas: 4.14

# %%
df['Produtividade'] = df['Tarefas Concluídas'] / df['Horas Trabalhadas']
media_produtividade = df['Produtividade'].mean()
print(f'Média Diária de Produtividade (Tarefas Concluídas por Hora): {media_produtividade:.2f}')
# Out:
# Média Diária de Produtividade (Tarefas Concluídas por Hora): 0.66

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Data', y='Horas Trabalhadas', data=df, palette='viridis')
plt.title('Horas Trabalhadas por Dia')
plt.xlabel('Data')
plt.ylabel('Horas Trabalhadas')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Data', y='Tarefas Concluídas', data=df, marker='o', color='b')
plt.title('Tarefas Concluídas por Dia')
plt.xlabel('Data')
plt.ylabel('Tarefas Concluídas')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Data', y='Bugs Corrigidos', data=df, marker='o', color='r')
plt.title('Bugs Corrigidos por Dia')
plt.xlabel('Data')
plt.ylabel('Bugs Corrigidos')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Data', y='Produtividade', data=df, marker='o', color='g')
plt.title('Produtividade Diária (Tarefas Concluídas por Hora)')
plt.xlabel('Data')
plt.ylabel('Produtividade')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Análise e Insights
#
# ## Total de Horas Trabalhadas
# O total de horas trabalhadas ao longo da semana foi de {total_horas_trabalhadas} horas. A média diária de horas trabalhadas foi de {media_horas_trabalhadas:.2f} horas por dia.
#
# ## Total de Bugs Corrigidos
# O total de bugs corrigidos ao longo da semana foi de {total_bugs_corrigidos}. A média diária de bugs corrigidos foi de {media_bugs_corrigidos:.2f} por dia.
#
# ## Total de Tarefas Concluídas
# O total de tarefas concluídas ao longo da semana foi de {total_tarefas_concluidas}. A média diária de tarefas concluídas foi de {media_tarefas_concluidas:.2f} por dia.
#
# ## Produtividade Diária
# A produtividade média diária, medida em tarefas concluídas por hora, foi de {media_produtividade:.2f}.
#
# # Conclusão
# A análise dos dados ao longo da semana permite identificar os dias de maior e menor produtividade, possibilitando ajustes no gerenciamento de tempo e alocação de recursos para melhorar o desempenho do projeto.
